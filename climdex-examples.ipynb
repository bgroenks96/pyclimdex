# %%
from climdex.temperature import count_frost_days
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ac02f6b441e8> in <module>
# ----> 1 from climdex.temperature import count_frost_days
#
# ~/generative-downscaling/climdex/climdex/temperature.py in <module>
#       1 import xarray as xr
#       2 import numpy as np
# ----> 3 import utils
#       4 from typing import Union
#       5
#
# ModuleNotFoundError: No module named 'utils'
